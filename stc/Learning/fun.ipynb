# %%
w,b,alpha=0.182,0.0645,0.01
y=[2,2.8,3.6,4.5]
x=[1,2,3,4]

# %%
for i in range(10):
    for i in range(len(x)):
        y_new=w*x[i]+b
        error=y_new-y[i]
        w=w-alpha*error*2
        b=b-alpha*error
