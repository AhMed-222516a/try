# %%
# f = open('file.txt')
f = open("file.txt", "rt")
# print(f)  #just print the direction
b = f.read().splitlines()
b = "\n".join(b)
f.close()
print(b)
# Out:
# <_io.TextIOWrapper name='file.txt' mode='rt' encoding='cp1252'>
# Hello! Welcome to demofile.txt
# This file is for testing purposes.
# Good Luck!

# %%
f = open('file.txt')
for i , line in enumerate(f):
    print(f"the line {i} have \n{len(line)} characters \n, data is: {line}")
f.close()
# Out:
# the line 0 have
# 31 characters
# , data is: Hello! Welcome to demofile.txt
#
# the line 1 have
# 35 characters
# , data is: This file is for testing purposes.
#
# the line 2 have
# 10 characters
# , data is: Good Luck!

# %%
with open("file.txt") as f:
  print(f.readline())
# Out:
# Hello! Welcome to demofile.txt

# %%
with open("file.txt") as f:
  print(f.readline())
  print(f.readline())
  print(f.readline())
# Out:
# Hello! Welcome to demofile.txt
#
# This file is for testing purposes.
#
# Good Luck!

# %%
with open('file.txt') as f:
  for line in f:
    print(line.strip()) # strip() to remove the extra new line character at the end of each line
# Out:
# Hello! Welcome to demofile.txt
# This file is for testing purposes.
# Good Luck!

# %%
with open("file.txt","a") as f:
  f.write("\nNow the file has more content!")
with open("file.txt") as f:
  print(f.read())
# Out:
# Hello! Welcome to demofile.txt
# This file is for testing purposes.
# Good Luck!
# Now the file has more content!
# Now the file has more content!

# %%
with open("demofile.txt", "w") as f:
  f.write("Woops! I have deleted the content!")

#open and read the file after the overwriting:
with open("demofile.txt") as f:
  print(f.read())
f= open("demofile.txt", "r")
print(f.read()) # this will not work because the file is closed after the with statement
# Out:
# Woops! I have deleted the content!
# Woops! I have deleted the content!

# %%
with open("demofile.txt") as f:
  print(f.read())
# Out:
# Woops! I have deleted the content!

# %%
f = open("myfile.txt", "x")

# %%
from pathlib import Path
my_file = Path("myfile.txt")

# %%
for file in Path(".").glob("*.txt"):
  print(file)
# Out:
# demofile.txt
# file.txt
# myfile.txt

# %%
f.close() # تأكد من تنفيذ هذا السطر أولاً
import os
# os.remove("myfile.txt")
for file in Path(".").glob("*.txt"):
  print(file)
# Out:
# demofile.txt
# file.txt

# %%
import os
if os.path.exists("myfile.txt"):
    os.remove("myfile.txt")
else:
    print("The file does not exist")
# Out:
# The file does not exist

# %%
import os
if os.path.exists("myfile.txt"):
    os.rmdir("myfile.txt")
else:
    print("The directory does not exist")
# Out:
# The directory does not exist
