# %% [markdown]
# Task_1

# %%
email="Amit_ml@gmail.com"

# %%
#if it not have he will return error
x=email.find("@")
print(x)
#to see if it agter @ if not he will reurn email.index("@")
y=email.index("@")+email[email.index("@"):].find(".")
print(y)
# Out:
# 7
# 13

# %%
print(email[:x])
# Out:
# Amit_ml

# %%
print(email[x+1:y])
# Out:
# gmail

# %%
print(email)
domn=email.split("@")
print(domn[1][:domn[1].find(".")])
# Out:
# Amit_ml@gmail.com
# gmail

# %% [markdown]
# Task_2

# %%
name="###!!@mocleW EPGTQ!!!6789"

# %%
na=name.split(" ")
n1=na[0].strip("!@#123456789")
l1=len(n1)
n1=n1[-1:-l1-1:-1]
n2=na[1].strip("!@#123456789")
n2=n2[1:]
print(n1+" "+n2)
# Out:
# Welcom PGTQ

# %% [markdown]
# Task_3

# %%
code="&&&**$gnirtS PLIO!!@1234"
Data=code.strip("&*$!@1234")
c1=code[0:code.find(code.strip("&*$!@1234"))]
c2=code[code.find(code.strip("&*$!@1234"))+len(Data):]
print(c1+c2)
# Out:
# &&&**$!!@1234

# %%
Data=Data.split()
print(Data)
D=Data[0][-1::-1]
print(D)
# Out:
# ['gnirtS', 'PLIO']
# String

# %%
D2=Data[1].replace("I","E").replace("O","U")
print(D2)
# Out:
# PLEU

# %%
print("if you want it without char\n"+D+D2)
print("with full encodding\n"+c1+D+D2+c2)
# Out:
# if you want it without char
# StringPLEU
# with full encodding
# &&&**$StringPLEU!!@1234

# %% [markdown]
# Task_4

# %% [markdown]
# task 3 is the same point of task 4 i could solve it by make it function

# %%
def Decode(code,a1,a2):
    code.strip()
    Data=code.strip("#&*$!@123456789")
    # c1=code[0:code.find(code.strip("&*$!@1234"))]
    # c2=code[code.find(code.strip("&*$!@1234"))+len(Data):]
    Data=Data.split()
    D=Data[0][-1::-1]
    D2=Data[1].replace(a1[0],a1[1]).replace(a2[0],a2[1])
    return D+" "+D2
print(Decode("##$$$@!yalpstcejorp EPUVT****9887",["E","A"],["U","O"]))
# Out:
# projectsplay APOVT
