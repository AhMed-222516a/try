# %%
email="Amit_ml@gmail.com"

# %% [markdown]
# check if it have @ one and at least one "." after the "@"

# %%
#if it not have he will return error
x=email.find("@")
print(x)
#to see if it agter @ if not he will reurn email.index("@")
y=email.index("@")+email[email.index("@"):].find(".")
print(y)
# Out:
# 7
# 13

# %%
print(email[:x])
# Out:
# Amit_ml

# %%
print(email[x+1:y])
# Out:
# gmail

# %%
print(email)
domn=email.split("@")
print(domn[1][:domn[1].find(".")])
# Out:
# Amit_ml@gmail.com
# gmail
