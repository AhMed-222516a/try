# %%
def revers_vocab(s):
    """
    param_1 = recive txt from user
    type param : string


    return: return the reversed the string
    type return : string
    """
    st_1=s.split(" ")
    new_st=st_1[::-1]
    new_st=" ".join(new_st)
    return new_st

# %%
print(revers_vocab("Hello World from OpenAI"))
# Out:
# OpenAI from World Hello

# %%
def fun(s):
    lst = s.split(" ")
    # print(lst)
    new_lst = lst[::-1]
    print(new_lst)
    new_str = ""
    for i in new_lst:
        new_str += i + " "
        print(new_str)
    new_str = new_str[:-1]
    return new_lst
s = "Hello World . to the "
fun('hello world')
# Out:
# ['world', 'hello']
# world
# world hello
# ['world', 'hello']

# %%
import random 
def generate_passcode(Length):
    char="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    password=""
    for _ in range(Length):
        password +=random.choice(char)
    return password

# %%
password_length=8
#print(generate_passcode(password_length))
x=[]
for _ in range(5):
    x.append(generate_passcode(password_length))
print(x)
# Out:
# ['4hwOuiDb', 'n*EmuW2o', 'J@y#RlE%', 'k20MWPUr', 'mJ&r^CIt']

# %% [markdown]
# how to make this word convert data from lests like excel or jason

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
def count_words(words):   
    """  
    pram_1 = list of words
    type pram_1 : list
    
    return : dictionary of words and their counts
    type return : dictionary
    """
    unique_words = set(words) # should be flixable for any tybe of files or lists
    # print(unique_words)
    counts = {word:0 for word in unique_words} # <<=============
    for i in unique_words:
        for j in words:
            if i == j:
                counts[i] += 1
    return counts
print(count_words(words))
# Out:
# {'No': 3, 'Ali': 4, 'Hi': 2, 'Welcome': 1}

# %%
import random 
import time

response = {
    "hello"  : ["hello!","Hi there!","Greetings!"],
    "how are you" :["I'm doing well, thank you", "i'm fine, how are you?"],
    "goodbye" :["Goodbye", "see you later", "farewell!"],
    "default" : ["i'm sorry, i did not understand. ","could you please rephrase that?"]
}

def get_response(user_input):
    for key in response :
        if key in user_input:
            return random.choice(response[key])
    return random.choice(response["default"])

def chatbot():
    print("chatbot: Hi How can i help you today?")
    while True:
        user_input = input("user:").lower()
        response = get_response (user_input)
        print("chatbot: ", response)

        if user_input == "goodbye":
            break
chatbot()
# Out:
# welcome to
# chatbot:  i'm sorry, i did not understand.
# chatbot:  farewell!

# %% [markdown]
# OOP

# %%
"""
this class


"""
class Student_info:
    
    studen_name="depi"
    std_age=20
    std_gpa=3.99
    gender="male"
    
    def std_info(x):
        print("hello world")

# %%
s1=Student_info()

# %%
s1.std_info()
# Out:
# hello world

# %%
class test:
    def info (self):
        print(self)

# %%
a=test()
#a.info("aa")
print(a)
print(hex(id(a)))
# Out:
# ...
# 0x16dde4c7aa0

# %%
class Student:
    def __init__(self):
        print("hallo world")

# %%
s1=Student()
# Out:
# hallo world

# %%
class password_generator:
    import random 
    def __init__(self, length):
        self.length = 8
        self.charachter="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"


        char="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"


    def generate_passcode(self, length):
        chars="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
        password=""
        for _ in range(self.length):
            password +=random.choice(chars)
        return password
if __name__ == "__main__":
    generator = password_generator(8)
    random_password=generator.generate_passcode (8)
    print(random_password)
# Out:
# hqB#rvV7
