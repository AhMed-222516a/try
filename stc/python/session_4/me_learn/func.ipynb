# %%
class info:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        return f"Hello, my name is {self.name} and I am {self.age} years old."

# %%
n1=info
# n1.name="ahmed"
# n1.age=22
print(n1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 n1=info
#       2 # n1.name="ahmed"
#       3 # n1.age=22
# ----> 4 print(n1.show())
#
# AttributeError: type object 'ahmed' has no attribute 'show'
