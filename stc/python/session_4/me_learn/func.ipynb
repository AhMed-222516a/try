# %%
class info:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(self)

# %%
n1=info("aa", 20)
n1.greet()

# %%
d=[1,2,3,4,5]
d.index(min(d))
# Out:
# 0

# %%
print("hallo")
# Out:
# hallo

# %%
def user_into(x,y):
    """
    param_1 : take first number from user
    type:pram_1: int
    param_2 : take scond number from user
    type:pram_1: int

    return: sum then sub then nmutiply then devide 
    typer_return:int
    """
    return [f"num_1 is {x} , num_2 is {y} add "+ str(x+y),"sub "+ str(x-y),"mutiply " + str(x*y),"devide "+ str(x/y)]


x= user_into(1,2)
print(x)
# Out:
# ['num_1 is 1 , num_2 is 2 add 3', 'sub -1', 'mutiply 2', 'devide 0.5']
