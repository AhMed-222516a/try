# %%
class info:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(self)

# %%
n1=info("aa", 20)
n1.greet()

# %%
d=[1,2,3,4,5]
d.index(min(d))
# Out:
# 0

# %%
print("hallo")
# Out:
# hallo
