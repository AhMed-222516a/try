# %%
list_1=[1,2,3,4,"amit","learning",True,[1,2,3,"True",["ml","dl","ds"]]]

# %%
list_1.append("new_item")

# %%
list_1.extend([1,2,3])
print (list_1)
# Out:
# [1, 2, 3, 4, 'amit', 'learning', True, [1, 2, 3, 'True', ['ml', 'dl', 'ds']], 'new_item', 1, 2, 3]

# %%
list_1.insert(2,"inserted_item")
list_1.remove(2)
print (list_1)
# Out:
# [1, 'inserted_item', 'inserted_item', 'inserted_item', 3, 4, 'amit', 'learning', True, [1, 2, 3, 'True', ['ml', 'dl', 'ds']], 'new_item', 'new_item', 'new_item', 'new_item', 1, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a=["amit","learning","python","python2"]
a.remove("python2") 
a.pop()
print (a)
# Out:
# ['amit', 'learning']

# %%
list_1=[1,2,3]
list_1.extend([1,2,3])
print (list_1)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
del list_1

# %%
list_1=[1,2,3]

# %%
list_1*2
len(list_1)
# Out:
# 3

# %%
ls=["amit","learning","python","machine_learning","deep learning"]
i=input("enter which do you remove:")
ls.remove(i)
print (ls)
# Out:
# ['learning', 'python', 'machine_learning', 'deep learning']

# %%
dict_1={"Key1":1,"key2":,"key3",4:}

# %%
num1=int(input("Enter first number: "))
num2=int(input("Enter second number: "))    
print("sum = ",num1+num2)
print("difference = ",num1-num2)
print("product = ",num1*num2)
print("division = ",num1/num2)
# Out:
# sum =  3
# difference =  -1
# product =  2
# division =  0.5

# %%
i=int(input("Enter your dgree"))
if 90<=i<=100:
    print ("A grade")
elif 90>=i>=80:
    print ("B grade")
elif 80>=i>=70:
    print ("C grade")   
elif 70>=i>=60:
    print ("D grade")
elif 0<i<60:
    print ("F grade")
else:
    print ("Invalid input")
# Out:
# Invalid input
